# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np
f = h5py.File('QB6_single_shot_raw_trace_10k_records.hdf5', 'r')

# %% [markdown]
# ### Get Hyperparameters

# %%
skip_time = None
integration_time = None

channels = list(f['Channels'])
for channel in channels:
    channel_name = list(channel)[0]
    
    if 'Skip time' in channel_name:
        print(channel)
        #skip_time = channel[]

    if 'Integration time' in channel_name:
        print(channel)
        #skip_time = channel[]
# Out:
# ('FPGA 10q BL - Integration time', 'Keysight PXI Digitizer FPGA Demod q10 - PXI: 18, FPGA 10q BL at localhost', 'Integration time', 's', 's', 1., 0., 1., inf, 0., '', 'Nothing', False, '', False, 1., False)
# ('FPGA 10q BL - Skip time', 'Keysight PXI Digitizer FPGA Demod q10 - PXI: 18, FPGA 10q BL at localhost', 'Skip time', 's', 's', 1., 0., 1., inf, 4.e-08, '', 'Nothing', False, '', False, 1., False)
# ('FPGA 10q BR - Integration time', 'Keysight PXI Digitizer FPGA Demod q10 - PXI: 17, FPGA 10q BR at localhost', 'Integration time', 's', 's', 1., 0., 1., inf, 0., '', 'Nothing', False, '', False, 1., False)
# ('FPGA 10q BR - Skip time', 'Keysight PXI Digitizer FPGA Demod q10 - PXI: 17, FPGA 10q BR at localhost', 'Skip time', 's', 's', 1., 0., 1., inf, 4.e-08, '', 'Nothing', False, '', False, 1., False)

# %%
print(np.array(f['Data']['Channel names']))
print(np.array(f['Data']['Data']).flatten())
#list(f['Data'].keys())
# Out:
# [('FPGA Voltage, QB1', 'Real') ('FPGA Voltage, QB1', 'Imaginary')
#  ('FPGA Voltage, QB2', 'Real') ('FPGA Voltage, QB2', 'Imaginary')
#  ('FPGA Voltage, QB3', 'Real') ('FPGA Voltage, QB3', 'Imaginary')
#  ('FPGA Voltage, QB4', 'Real') ('FPGA Voltage, QB4', 'Imaginary')
#  ('FPGA Voltage, QB5', 'Real') ('FPGA Voltage, QB5', 'Imaginary')
#  ('FPGA Voltage, QB6', 'Real') ('FPGA Voltage, QB6', 'Imaginary')
#  ('FPGA Voltage, QB7', 'Real') ('FPGA Voltage, QB7', 'Imaginary')
#  ('FPGA Voltage, QB8', 'Real') ('FPGA Voltage, QB8', 'Imaginary')
#  ('FPGA Voltage, QB9', 'Real') ('FPGA Voltage, QB9', 'Imaginary')
#  ('FPGA Voltage, QB10', 'Real') ('FPGA Voltage, QB10', 'Imaginary')
#  ('FPGA Voltage, QB11', 'Real') ('FPGA Voltage, QB11', 'Imaginary')
#  ('FPGA Voltage, QB12', 'Real') ('FPGA Voltage, QB12', 'Imaginary')
#  ('FPGA Voltage, QB13', 'Real') ('FPGA Voltage, QB13', 'Imaginary')
#  ('FPGA Voltage, QB14', 'Real') ('FPGA Voltage, QB14', 'Imaginary')
# ...

# %%
foo = np.array(f['Traces']['FPGA Single-shot, QB6'])
plt.plot(foo[:,0,0])
plt.plot(foo[:,1,0])
plt.show()

# %%
list(f['Traces'].keys())
# Out:
# ['FPGA 10q BL - Ch1 - Signal',
#  'FPGA 10q BL - Ch1 - Signal_N',
#  'FPGA 10q BL - Ch1 - Signal_t0dt',
#  'FPGA 10q BL - Ch2 - Signal',
#  'FPGA 10q BL - Ch2 - Signal_N',
#  'FPGA 10q BL - Ch2 - Signal_t0dt',
#  'FPGA 10q BR - Ch1 - Signal',
#  'FPGA 10q BR - Ch1 - Signal_N',
#  'FPGA 10q BR - Ch1 - Signal_t0dt',
#  'FPGA 10q BR - Ch2 - Signal',
#  'FPGA 10q BR - Ch2 - Signal_N',
#  'FPGA 10q BR - Ch2 - Signal_t0dt',
#  'FPGA Single-shot, QB6',
#  'FPGA Single-shot, QB6_N',
#  'FPGA Single-shot, QB6_t0dt',
#  'Time stamp']

# %%
ch1_signal = f['Traces']['FPGA 10q BL - Ch1 - Signal']
ch1_signal = np.array(ch1_signal)[:,0,0]

ch1_signal_n = f['Traces']['FPGA 10q BL - Ch1 - Signal_t0dt']
ch1_signal_n = np.array(ch1_signal_n)
print(ch1_signal_n)
# Out:
# [[0.e+00 2.e-09]]

# %%
plt.hist2d(foo[:,0,0], foo[:,1,0], bins = 100)
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=0211f19d-54e4-44e5-ab1c-ce7a6a2d44df' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
